# %% [markdown]
# # __TASK 14 - LINEAR REGRESSION__
# - It provides a linear relationship between an independent variable and a dependent variable to predict the outcome of future events
#
# There are two types of Regression
# 1. Simple Linear Regression (One independent variable and one dependent variable).
# 2. Multiple Linear Regression ( One dependent variable and two or more independent variables)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split

# %% [markdown]
# # __1. Simple Linear Regression__
# - One independent variable and one dependent variable.

# %%
df = pd.read_csv('D:\DS\Salary_Data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\baigs\AppData\Local\Temp\ipykernel_9684\3382097918.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DS\Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x= df[['YearsExperience']]
y = df[['Salary']]

# x.head()

# %%
sns.boxplot(data=df, y=df['YearsExperience'])
# Out:
# <Axes: ylabel='YearsExperience'>

# %%
sns.boxplot(data=df, y=df['Salary'])
# Out:
# <Axes: ylabel='Salary'>

# %%
# Splitting data into Training Data and Test data 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test  = train_test_split(x, y, test_size=0.2, random_state= 42)

# %%
# Fitting Simple Linear Regression to training set

from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %% [markdown]
# __Ploting on the Basis of Traning Data__

# %%
plt.scatter(x_train,y_train, color = 'red')
plt.plot(x_train, model.predict(x_train))         # Making Line

plt.xlabel('Year of Experiance')
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# __Ploting on the Basis of testing Data__

# %%
plt.scatter(x_test,y_test, color='red' )
plt.plot(x_test, model.predict(x_test))

plt.xlabel('Year of Experiance')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# # __Predicting Salary__

# %%
model.predict([[3]])
# Out:
# c:\Users\baigs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[53593.02898087]])

# %%
model.predict([[6]])
# Out:
# c:\Users\baigs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[81864.47494996]])

# %%
model.predict([[3],[4],[5],[6]])
# Out:
# c:\Users\baigs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[53593.02898087],
#        [63016.8443039 ],
#        [72440.65962693],
#        [81864.47494996]])

# %% [markdown]
# # __2. MULTIPLE LINEAR REGRESSION__

# %%
df = pd.read_csv('D:\DS\multiple_linear_regression_dataset.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\baigs\AppData\Local\Temp\ipykernel_9684\4274884124.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DS\multiple_linear_regression_dataset.csv')
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
x = df[["age","experience"]]
y = df['income']

# %%
sns.boxplot(data=df, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(data=df, y='experience')
# Out:
# <Axes: ylabel='experience'>

# %%
sns.boxplot(data=df, y='income')
# Out:
# <Axes: ylabel='income'>

# %% [markdown]
# There are no outliers in age but one in experiance & income which minimal so it can be ignored

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression().fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
# PREDICTING INCOME ON THE BASIS OF AGE AND EXPERIANCE
model.predict([[20, 5]])
# Out:
# c:\Users\baigs\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40267.90093445])
